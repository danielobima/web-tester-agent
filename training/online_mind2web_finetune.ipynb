# %%
# Install all required packages
# !pip install datasets google-cloud-aiplatform pandas huggingface_hub ipywidgets
# Out:
# Requirement already satisfied: datasets in ./.venv/lib/python3.10/site-packages (4.8.5)
# Requirement already satisfied: google-cloud-aiplatform in ./.venv/lib/python3.10/site-packages (1.150.0)
# Requirement already satisfied: pandas in ./.venv/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: huggingface_hub in ./.venv/lib/python3.10/site-packages (1.14.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.10/site-packages (8.1.8)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from datasets) (3.29.0)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.10/site-packages (from datasets) (2.2.6)
# Requirement already satisfied: pyarrow>=21.0.0 in ./.venv/lib/python3.10/site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in ./.venv/lib/python3.10/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in ./.venv/lib/python3.10/site-packages (from datasets) (2.33.1)
# Requirement already satisfied: httpx<1.0.0 in ./.venv/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in ./.venv/lib/python3.10/site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.10/site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in ./.venv/lib/python3.10/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in ./.venv/lib/python3.10/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.10/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in ./.venv/lib/python3.10/site-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: typer>=0.20.0 in ./.venv/lib/python3.10/site-packages (from huggingface_hub) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in ./.venv/lib/python3.10/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.venv/lib/python3.10/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in ./.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (3.13)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in ./.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.30.3)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.51.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.28.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (6.33.6)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=1.32.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.10.1)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.41.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.66.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.75.0)
# Requirement already satisfied: pydantic<3 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.13.4)
# Requirement already satisfied: docstring_parser<1 in ./.venv/lib/python3.10/site-packages (from google-cloud-aiplatform) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in ./.venv/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.75.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in ./.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in ./.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.80.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./.venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (48.0.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in ./.venv/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in ./.venv/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in ./.venv/lib/python3.10/site-packages (from google-cloud-storage<4.0.0,>=1.32.0->google-cloud-aiplatform) (1.8.0)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (1.9.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.66.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./.venv/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas) (2026.2)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.10/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.10/site-packages (from ipywidgets) (8.39.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./.venv/lib/python3.10/site-packages (from ipywidgets) (5.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.venv/lib/python3.10/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.venv/lib/python3.10/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (3.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform) (0.6.3)
# Requirement already satisfied: click>=8.2.1 in ./.venv/lib/python3.10/site-packages (from typer>=0.20.0->huggingface_hub) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.10/site-packages (from typer>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in ./.venv/lib/python3.10/site-packages (from typer>=0.20.0->huggingface_hub) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/lib/python3.10/site-packages (from typer>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface_hub) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface_hub) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %% [markdown]
# # Online-Mind2Web Fine-tuning with Vertex AI
#
# This notebook demonstrates how to:
# 1. Load data from the gated `osunlp/Online-Mind2Web` dataset on Hugging Face.
# 2. Prepare the data for fine-tuning an LLM on Google Cloud Vertex AI.
# 3. **Integrate with `ai-qa-bot`**: Use the agent CLI to perform tasks and record actions.
# 4. Compare the agent's performance against the gold standard reference steps.

# %% [markdown]
# ## 1. Setup and Authentication
#
# First, authenticate with Hugging Face and Google Cloud.

# %%
from huggingface_hub import notebook_login

# You need to accept the conditions for osunlp/Online-Mind2Web on Hugging Face first.
# After that, run this cell and enter your Hugging Face Token.
notebook_login()

# %%
import os
from google.cloud import aiplatform

PROJECT_ID = "your-project-id"  # @param {type:"string"}
REGION = "us-central1"          # @param {type:"string"}

aiplatform.init(project=PROJECT_ID, location=REGION)
# Out:
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.resourcemanager_v3 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.resourcemanager_v3 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.instance_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.instance_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.params_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.params_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.predict.prediction_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.predict.prediction_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform.v1.schema.trainingjob.definition_v1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1.schema.trainingjob.definition_v1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.instance_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.instance_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.params_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.params_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.predict.prediction_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.predict.prediction_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)
# /home/daniel/projects/qa-tester/training/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.aiplatform.v1beta1.schema.trainingjob.definition_v1beta1 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.aiplatform.v1beta1.schema.trainingjob.definition_v1beta1 past that date.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## 2. Load Dataset
#
# We use the `datasets` library to pull a record from the `osunlp/Online-Mind2Web` dataset.

# %%
# from datasets import load_dataset

# # Load the dataset in streaming mode to quickly pull one record
# dataset = load_dataset("osunlp/Online-Mind2Web", split="test", streaming=True)
# record = next(iter(dataset))

# print("Task ID:", record.get('task_id'))
# print("Website:", record.get('website'))
# print("Task Description:", record.get('confirmed_task'))

import json
with open("sample_record.json", "r") as f:
    record = json.load(f)
print("Task ID:", record.get('task_id'))
print("Website:", record.get('website'))
print("Task Description:", record.get('confirmed_task'))
# Out:
# Task ID: test_task_001
# Website: file:///home/daniel/projects/qa-tester/training/test_site.html
# Task Description: Enter the name 'John Doe' into the name input field and click the submit button to see the success message.

# %% [markdown]
# ## 3. Prepare for Vertex AI Fine-tuning
#
# Vertex AI Gemini fine-tuning expects a JSONL format where each line represents a full conversation structure.

# %%
import json

def format_to_gemini_jsonl(record):
    """
    Formats a dataset record into Vertex AI Gemini fine-tuning JSONL format.
    """
    system_instruction = "You are a web agent that performs tasks on websites. Provide the action to take."
    user_prompt = f"Website: {record['website']}\nTask: {record['confirmed_task']}"
    
    # For finetuning, the gold standard would be the actual steps taken.
    gold_standard = f"Action: Click on the button related to {record['confirmed_task']}"
    
    entry = {
        "systemInstruction": {
            "role": "system",
            "parts": [{"text": system_instruction}]
        },
        "contents": [
            {
                "role": "user",
                "parts": [{"text": user_prompt}]
            },
            {
                "role": "model",
                "parts": [{"text": gold_standard}]
            }
        ]
    }
    return entry

training_sample = format_to_gemini_jsonl(record)
print("Formatted Sample for Vertex AI:")
print(json.dumps(training_sample, indent=2))
# Out:
# Formatted Sample for Vertex AI:
# {
#   "systemInstruction": {
#     "role": "system",
#     "parts": [
#       {
#         "text": "You are a web agent that performs tasks on websites. Provide the action to take."
#       }
#     ]
#   },
#   "contents": [
#     {
#       "role": "user",
#       "parts": [
#         {
#           "text": "Website: file:///home/daniel/projects/qa-tester/training/test_site.html\nTask: Enter the name 'John Doe' into the name input field and click the submit button to see the success message."
#         }
#       ]
#     },
#     {
#       "role": "model",
#       "parts": [
#         {
#           "text": "Action: Click on the button related to Enter the name 'John Doe' into the name input field and click the submit button to see the success message."
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## 4. Run Test with ai-qa-bot CLI
#
# We use the `ai-qa-bot` agent to execute the task on the live website. We stream the output to see logs in real-time.

# %%
import subprocess
import os
import sys

def run_agent_test(record):
    # Path to the ai-qa-bot directory
    agent_dir = "../ai-qa-bot"
    goal = record['confirmed_task']
    url = record['website']
    task_id = record['task_id']
    output_file = f"../training/results/{task_id}.json"
    
    os.makedirs("../training/results", exist_ok=True)
    
    # CLI Command: npm run cli -- record "<Goal>" "<StartUrl>" "<OutputFile>"
    cmd = [
        "npm", "run", "cli", "--", 
        "record", goal, url, output_file,
        "--no-artifacts"
    ]
    
    print(f"--- Starting Agent for Task: {task_id} ---")
    print(f"Goal: {goal}")
    print(f"URL: {url}")
    print("\n--- Agent Output (Streaming) ---\n")
    
    try:
        # Using Popen to stream output
        process = subprocess.Popen(
            cmd, 
            cwd=agent_dir, 
            stdout=subprocess.PIPE, 
            stderr=subprocess.STDOUT, 
            text=True,
            bufsize=1
        )
        
        # Stream stdout line by line
        for line in iter(process.stdout.readline, ''):
            print(line, end='', flush=True)
            
        process.stdout.close()
        return_code = process.wait()
        
        if return_code == 0:
            print("\n--- Agent Success ---")
            return output_file
        else:
            print(f"\n--- Agent Failed with return code {return_code} ---")
            return None
            
    except Exception as e:
        print(f"\n--- Error running agent: {e} ---")
        return None

result_path = run_agent_test(record)
# print("Uncomment the line above to run the agent test with streaming logs.")
# Out:
# --- Starting Agent for Task: test_task_001 ---
# Goal: Enter the name 'John Doe' into the name input field and click the submit button to see the success message.
# URL: file:///home/daniel/projects/qa-tester/training/test_site.html
#
# --- Agent Output (Streaming) ---
#
#
# > web-testing-agent@1.0.0 cli
# > ts-node src/cli.ts record Enter the name 'John Doe' into the name input field and click the submit button to see the success message. file:///home/daniel/projects/qa-tester/training/test_site.html ../training/results/test_task_001.json --no-artifacts
#
# [dotenv@17.3.1] injecting env (1) from .env -- tip: ⚙️  suppress all logs with { quiet: true }
# [Browser] New page opened: about:blank
# [CLI] Starting Record Mode...
# [Browser] Executing action: navigate
# [Browser] Active page set to: about:blank (TargetID: AA930CF74324A53EDD7E9D3C669F16BC)
# [Browser] Active page set to: about:blank (TargetID: AA930CF74324A53EDD7E9D3C669F16BC)
# [Browser] Page stabilized after 1065ms
# [Browser] Built Snapshot. Stats: { lines: 4, chars: 126, refs: 3, interactive: 2 }
# [Agent][Planner] Planning...
# [Browser] Executing action: type
# [TestSerializer] Saving test to: ../training/results/test_task_001.json
# [Browser] Page stabilized after 520ms
# [Browser] Built Snapshot. Stats: { lines: 4, chars: 136, refs: 3, interactive: 2 }
# [Agent][Asserter] Executing generated assertions...
# [Assert] Selected 1 assertions for verification:
#   1. [inputValueEquals] on page
# [Assert] Evaluating Assertion #1 [inputValueEquals]...
# [Assert] ❌ FAILED: Assertion #1 [inputValueEquals] - locator.inputValue: Error: Node is not an <input>, <textarea> or <select> element
# Call log:
#   - waiting for locator('body')
#
# [Agent][Asserter] Assertions FAILED: Assertion #1 [inputValueEquals]: locator.inputValue: Error: Node is not an <input>, <textarea> or <select> element
# Call log:
#   - waiting for locator('body')
#
# [Agent][Asserter] Executing generated assertions...
# [Assert] Selected 1 assertions for verification:
#   1. [valueEquals] on role="textbox" name="Enter your name"
# [Assert] Evaluating Assertion #1 [valueEquals]...
# [Assert] ✅ PASSED: Assertion #1 [valueEquals]
# [Browser] Page stabilized after 516ms
# [Browser] Built Snapshot. Stats: { lines: 4, chars: 136, refs: 3, interactive: 2 }
# [Agent][Planner] Planning...
# [Browser] Executing action: click
# [TestSerializer] Saving test to: ../training/results/test_task_001.json
# [Browser] Page stabilized after 512ms
# [Browser] Built Snapshot. Stats: { lines: 5, chars: 186, refs: 3, interactive: 2 }
# [Agent][Asserter] Executing generated assertions...
# [Assert] Selected 1 assertions for verification:
#   1. [textContains] on page
# [Assert] Evaluating Assertion #1 [textContains]...
# [Assert] ✅ PASSED: Assertion #1 [textContains]
# [Browser] Page stabilized after 512ms
# [Browser] Built Snapshot. Stats: { lines: 5, chars: 186, refs: 3, interactive: 2 }
# [Agent][Planner] Planning...
# [Agent] Planner indicates goal achieved: The feedback form has been submitted and the success message 'Thank you, John Doe! Form submitted successfully.' is displayed on the screen.
# [TestSerializer] Saving test to: ../training/results/test_task_001.json
# [TestSerializer] Saving test to: ../training/results/test_task_001.json
#
# --- Agent Success ---

# %% [markdown]
# ## 5. Compare against Gold Standard
#
# We compare the agent's actual steps with the human reference steps.

# %%
def compare_performance(result_path, record):
    if not result_path or not os.path.exists(result_path):
        print("Result file not found.")
        return
        
    with open(result_path, 'r') as f:
        data = json.load(f)
    
    print(data.get('steps'))
    agent_steps = len(data.get('steps', []))
    human_steps = record.get('reference_length')
    
    print(f"Task: {record['confirmed_task']}")
    print(f"Agent Steps: {agent_steps}")
    print(f"Human Reference Steps: {human_steps}")
    
    diff = agent_steps - human_steps
    if diff <= 0:
        print("Performance: Optimal (Matched or beat human steps!)")
    else:
        print(f"Performance: Sub-optimal ({diff} more steps than human)")

print(f"result_path {result_path}")
compare_performance(result_path, record)
# Out:
# result_path ../training/results/test_task_001.json
# [{'id': 'step-1', 'action': {'kind': 'type', 'text': 'John Doe', 'role': 'textbox', 'name': 'Enter your name'}, 'stateDescription': "The page displays a feedback form with a text input field for 'Name' [e2] and a 'Submit' button [e3].", 'actionIntent': "Type 'John Doe' into the name input field [e2] to satisfy the current task.", 'actionResult': "The name 'John Doe' was successfully entered into the input field.", 'verificationAssertions': [{'type': 'valueEquals', 'value': 'John Doe', 'role': 'textbox', 'name': 'Enter your name'}], 'taskId': 'TASK-1', 'stateSnapshot': '', 'issues': []}, {'id': 'step-2', 'action': {'kind': 'click', 'role': 'button', 'name': 'Submit'}, 'stateDescription': "The page displays a feedback form with the name 'John Doe' correctly entered into the input field [e2]. The 'Submit' button [e3] is currently enabled.", 'actionIntent': "Click the 'Submit' button [e3] to finalize the feedback submission.", 'verificationAssertions': [{'type': 'textContains', 'value': 'Thank you, John Doe! Form submitted successfully.'}], 'taskId': 'TASK-2', 'stateSnapshot': '', 'issues': []}]
# Task: Enter the name 'John Doe' into the name input field and click the submit button to see the success message.
# Agent Steps: 2
# Human Reference Steps: 2
# Performance: Optimal (Matched or beat human steps!)

# %% [markdown]
# ## 6. Next Steps: Batch Processing
